# %%
import matplotlib.pyplot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 import matplotlib.pyplot
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.2/7.2 MB 4.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.3/55.3 kB 2.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 163.6/163.6 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 4.8 MB/s eta 0:00:00
# ...
#      -------------------------------------- 965.4/965.4 kB 5.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as mb
# %matplotlib inline

# %%
movies=['avengers','age of ulton','infinity war','endgame']
percentage=[20,30,40,50]

# %%
mb.scatter(movies,percentage)

# %%
mb.plot(movies,percentage,linestyle='dashdot')

# %%
mb.plot(movies,percentage,linestyle='dotted')

# %%
mb.plot(movies,percentage,linestyle='solid')

# %%
mb.pie(percentage,labels=movies)
# Out:
# ([<matplotlib.patches.Wedge at 0x27afeb21570>,
# ...
#  [Text(0.9910657451172095, 0.47727213291294374, 'avengers'),
#   Text(-5.149471629032507e-08, 1.0999999999999988, 'age of ulton'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'infinity war'),
#   Text(0.4772722720983461, -0.9910656780890369, 'endgame')])

# %%
mb.bar(movies,percentage)
# Out:
# <BarContainer object of 4 artists>

# %%
import numpy as np

# %%
time=np.arange(0,10,0.05)

# %%
time
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  , 1.05,
#        1.1 , 1.15, 1.2 , 1.25, 1.3 , 1.35, 1.4 , 1.45, 1.5 , 1.55, 1.6 ,
#        1.65, 1.7 , 1.75, 1.8 , 1.85, 1.9 , 1.95, 2.  , 2.05, 2.1 , 2.15,
#        2.2 , 2.25, 2.3 , 2.35, 2.4 , 2.45, 2.5 , 2.55, 2.6 , 2.65, 2.7 ,
#        2.75, 2.8 , 2.85, 2.9 , 2.95, 3.  , 3.05, 3.1 , 3.15, 3.2 , 3.25,
#        3.3 , 3.35, 3.4 , 3.45, 3.5 , 3.55, 3.6 , 3.65, 3.7 , 3.75, 3.8 ,
#        3.85, 3.9 , 3.95, 4.  , 4.05, 4.1 , 4.15, 4.2 , 4.25, 4.3 , 4.35,
#        4.4 , 4.45, 4.5 , 4.55, 4.6 , 4.65, 4.7 , 4.75, 4.8 , 4.85, 4.9 ,
#        4.95, 5.  , 5.05, 5.1 , 5.15, 5.2 , 5.25, 5.3 , 5.35, 5.4 , 5.45,
#        5.5 , 5.55, 5.6 , 5.65, 5.7 , 5.75, 5.8 , 5.85, 5.9 , 5.95, 6.  ,
#        6.05, 6.1 , 6.15, 6.2 , 6.25, 6.3 , 6.35, 6.4 , 6.45, 6.5 , 6.55,
#        6.6 , 6.65, 6.7 , 6.75, 6.8 , 6.85, 6.9 , 6.95, 7.  , 7.05, 7.1 ,
# ...

# %%
amplitude=np.sin(time)

# %% [markdown]
# amplitude

# %%
amplitude
# Out:
# array([ 0.        ,  0.04997917,  0.09983342,  0.14943813,  0.19866933,
#         0.24740396,  0.29552021,  0.34289781,  0.38941834,  0.43496553,
#         0.47942554,  0.52268723,  0.56464247,  0.60518641,  0.64421769,
#         0.68163876,  0.71735609,  0.75128041,  0.78332691,  0.8134155 ,
#         0.84147098,  0.86742323,  0.89120736,  0.91276394,  0.93203909,
#         0.94898462,  0.96355819,  0.97572336,  0.98544973,  0.99271299,
#         0.99749499,  0.99978376,  0.9995736 ,  0.99686503,  0.99166481,
#         0.98398595,  0.97384763,  0.9612752 ,  0.94630009,  0.92895972,
#         0.90929743,  0.88736237,  0.86320937,  0.83689879,  0.8084964 ,
#         0.7780732 ,  0.74570521,  0.71147335,  0.67546318,  0.6377647 ,
#         0.59847214,  0.55768372,  0.51550137,  0.47203054,  0.42737988,
#         0.38166099,  0.33498815,  0.28747801,  0.23924933,  0.19042265,
#         0.14112001,  0.09146464,  0.04158066, -0.00840725, -0.05837414,
# ...

# %%
mb.plot(time,amplitude)

# %%
pip install seaborn
# Out:
# ...
#      -------------------------------------- 288.2/288.2 kB 4.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sn

# %%
sn.set(style='darkgrid')

# %%
random=np.random.randn(100)

# %%
random
# Out:
# array([-0.50822037, -0.6506194 ,  0.14656521, -0.29734079, -0.25949006,
#         0.95119496,  0.02958936,  0.90103131, -1.50827749,  1.92853779,
#        -0.88438563,  0.04795621,  0.51834658, -0.90041708, -2.14238797,
#         0.36862582,  0.0426778 ,  1.04284977,  1.3933604 ,  1.14550775,
#         0.25656397, -0.73342072, -0.07160919,  0.70917036,  0.20890724,
#         1.06370419,  0.17280151,  1.31954245,  1.1298121 ,  1.17605199,
#        -1.40952805,  0.5711013 ,  0.42778766, -1.07905333,  1.07960921,
#         1.93267136, -0.18878471,  0.12329845, -0.17667926,  2.44341389,
#        -1.7387684 ,  0.40462447,  1.73319043,  0.4731164 , -0.72600801,
#         0.36058896, -0.51558282, -1.04379158, -0.11167428, -1.8811018 ,
#         0.51514273,  0.33134166,  2.50653302,  1.5370031 , -1.33282039,
#         0.41977457,  0.447933  ,  0.60727683,  0.09908156,  0.19456851,
#         0.27131423, -1.42431994, -2.28404411,  0.05471197, -0.67823609,
# ...

# %%
sn.distplot(random)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9836\933703326.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(random)
# <AxesSubplot: ylabel='Density'>

# %%
sn.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tip=sn.load_dataset('tips')

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tip.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sn.relplot(x='total_bill',y='tip',data=tip)

# %%
sn.catplot(x='day',y='total_bill',kind='box',data=tip)

# %%
sn.regplot(x='total_bill',y='tip',data=tip)
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
pip install sklearn
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2936 sha256=7509242e168557998398d37eac654ef15cd25e7834acfe6d99e6d62ae591d999
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\c5\88\35\cc8a1e198b27a1d3d9d3f9b30090b9d5531778847835472ec4
# Successfully built sklearn
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn as sk
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [74], line 1
# ----> 1 import sklearn as sk
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import sklearn as sk
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 import sklearn as sk
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.preprocessing import Normalizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 from sklearn.preprocessing import Normalizer
#
# ModuleNotFoundError: No module named 'sklearn'
